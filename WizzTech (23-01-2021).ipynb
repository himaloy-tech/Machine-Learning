# %% [markdown]
# <h2>Numpy Array (Contd.)</h2>

# %%
import numpy as np

# %%
a = np.array([2, 7, 3, 9])

# %%
np.pi # Value of pi
# Out:
# 3.141592653589793

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.array([0,1,2,3])
y=np.array([0,2,4,6])
plt.plot(x,y)

# %%
x = np.array([0, np.pi/2, np.pi, 3*np.pi/2, 2*np.pi])
y = np.sin(x)
plt.plot(x, y)

# %%
x = np.array([0, np.pi/4, np.pi/2, np.pi, 3*np.pi/2, 2*np.pi])
y = np.sin(x)
plt.plot(x, y)

# %%
a = np.linspace(-2, 2, num=9)
a
# Out:
# array([-2. , -1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ])

# %%
x = np.linspace(0, 2*np.pi, num=5)
x
# Out:
# array([0.        , 1.57079633, 3.14159265, 4.71238898, 6.28318531])

# %%
x = np.linspace(0, 2*np.pi, num=5)
y = np.sin(x)
plt.plot(x, y)

# %%
x = np.linspace(0, 2*np.pi, num=10)
y = np.sin(x)
plt.plot(x, y)

# %%
x = np.linspace(0, 2*np.pi, num=20)
y = np.sin(x)
plt.plot(x, y)

# %%
x = np.linspace(0, 2*np.pi, num=50)
y = np.sin(x)
plt.plot(x, y)

# %% [markdown]
# <h2>2D Numpy Array</h2>

# %%
b = np.array([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
print(b)
# Out:
# [[11 12 13]
#  [21 22 23]
#  [31 32 33]]

# %%
b.shape
# Out:
# (3, 3)

# %% [markdown]
# <h2>Slicing</h2>

# %%
b[2, 1]
# Out:
# 32

# %%
b[0, 2]
# Out:
# 13

# %%
b[0][2]
# Out:
# 13

# %%
b.ndim
# Out:
# 2

# %%
b[1:, 2]
# Out:
# array([23, 33])

# %%
b[1:, 1:]
# Out:
# array([[22, 23],
#        [32, 33]])

# %%
b.size
# Out:
# 9

# %%
a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6], [7, 8]])
c = a + b
print(c)
# Out:
# [[ 6  8]
#  [10 12]]

# %%
a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6], [7, 8]])
c = b - a
print(c)
# Out:
# [[4 4]
#  [4 4]]

# %%
a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6], [7, 8]])
c = a * b
print(c)
# Out:
# [[ 5 12]
#  [21 32]]

# %%
a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6], [7, 8]])
c = np.dot(a, b)
print(c)
# Out:
# [[19 22]
#  [43 50]]

# %%
a = np.array([1, 2])
b = np.array([3, 4])
c = np.dot(a, b)
c
# Out:
# 11

# %%
a = [1, 2]
b = [3, 4]
c = np.dot(a, b)
c
# Out:
# 11

# %%
a = np.array([[1, 2], [3, 4], [5, 6]])
a
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
a.T
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %% [markdown]
# <h2>Scatter Plot</h2>

# %%
x = np.array([2, 3, 4, 9, 1, 7, 8])
y = np.array([3, 5, 7, 13, 2, 9, 6])
plt.scatter(x, y)
plt.show()
